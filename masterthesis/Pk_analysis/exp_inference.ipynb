# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Invesitgate model 218
txtname = "Pk_analysis/losses/loss_218.txt"
losses = pd.read_csv(txtname, sep=" ", header=None)

# %%
losses.columns = ["epoch", "train_loss", "val_loss"]
# Out:
# Index(['epoch', 'train_loss', 'val_loss'], dtype='object')

# %%
plt.plot(losses["epoch"], losses["train_loss"], label="train")
plt.plot(losses["epoch"], losses["val_loss"], label="val")
plt.legend()

# %% [markdown]
# ## Load the model

# %%
model_name = "Pk_analysis/models/model_218.pt"
