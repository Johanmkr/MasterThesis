# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import data3D as data

# %%
train, test = data.create_data(np.arange(0,200), np.arange(200,250))
# Out:
# ...
# Normalizing data: 100%|██████████| 400/400 [00:00<00:00, 27915.04it/s]
# Checked! Loaded 400 power spectra
# ...
# Normalizing data: 100%|██████████| 100/100 [00:00<00:00, 27181.03it/s]
# Checked! Loaded 100 power spectra

# %%
for i in range(200):
    print(len(train[i]["Pk"]))
# Out:
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# ...
